# %%
from main import build_dataset
seed_urls = ['https://inshorts.com/en/read/technology',
             'https://inshorts.com/en/read/sports',
             'https://inshorts.com/en/read/world']

# %%
build_dataset(seed_urls)
# Out:
#                                         news_headline  \
# 0   IIT-Ropar develops device to sanitise currency...
# 1   Amazon says warehouse worker has coronavirus a...
# 2   Facebook sues Indian techie over deceptive ads...
# 3   Google Search for 'Living room concert' increa...
# 4   Facebook adds 'Quiet Mode' to help users spend...
# ..                                                ...
# 69  SpiceJet operates 1st freighter to Vietnam, ca...
# 70           Yemen reports its first coronavirus case
# 71  Brazil's SC bars Prez Bolsonaro from easing CO...
# 72  Struggle against COVID-19 far from over: South...
# 73  Canada projects 11,000 to 22,000 coronavirus d...
#
#                                          news_article news_category
# 0   Indian Institute of Technology, Ropar has deve...    technology
# 1   An Amazon warehouse in the US confirmed its fi...    technology
# 2   Facebook has filed a lawsuit against an Indian...    technology
# 3   Google Trends data shows the search for 'Livin...    technology
# 4   Facebook is launching a "Quiet Mode" on iOS to...    technology
# ..                                                ...           ...
# 69  SpiceJet operated its first freighter service ...         world
# 70  Yemen on Friday reported its first case of the...         world
# 71  Brazil's Supreme Court has ruled to bar Presid...         world
# 72  South African President Cyril Ramaphosa has ex...         world
# 73  The Canadian death toll from the coronavirus o...         world
#
# [74 rows x 3 columns]
